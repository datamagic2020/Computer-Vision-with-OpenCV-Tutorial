# %% [markdown]
# 1. import packages

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# 2. load sample image

# %%
image= cv2.imread("C:\images\obama\obama1.jpeg")

# %% [markdown]
# 3. display loaded image

# %%
plt.title('Original Image') 
plt.imshow(image)

# %% [markdown]
# 4. crop image

# %% [markdown]
# -extract Region of interest(ROI)
# -ex face,sign board, road lanes etc

# %%
cropped = image[100:1200,0:1500]

# %% [markdown]
# 5. display cropped image

# %%
plt.title('Cropped Image') 
plt.imshow(cropped)
