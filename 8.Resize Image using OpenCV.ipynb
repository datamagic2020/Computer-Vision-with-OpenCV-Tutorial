# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting matplotlib
#
#   Downloading https://files.pythonhosted.org/packages/1f/99/1b9c3b3a871df3174d17910f3d7422a24280b8355377fec0fb1264a20e0c/matplotlib-3.3.2-cp36-cp36m-win_amd64.whl (8.5MB)
# Collecting pillow>=6.2.0 (from matplotlib)
# You are using pip version 18.1, however version 20.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
#   Downloading https://files.pythonhosted.org/packages/3e/e5/93a31c3b6efaac82112510a2550f9a9cf1a2e6ce3d9492f6f3188cba3fbd/Pillow-8.0.0-cp36-cp36m-win_amd64.whl (2.0MB)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl
# Collecting certifi>=2020.06.20 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.15 in c:\justdoit\python\environments\opencv_env\lib\site-packages (from matplotlib) (1.19.1)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.1 in c:\justdoit\python\environments\opencv_env\lib\site-packages (from matplotlib) (2.8.1)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/2a/1e/f53031838c75cef71086ab7fc0dea1853d811ba3ec72465d782877223f09/kiwisolver-1.2.0-cp36-none-win_amd64.whl
# Requirement already satisfied: six in c:\justdoit\python\environments\opencv_env\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pillow, pyparsing, certifi, cycler, kiwisolver, matplotlib
# Successfully installed certifi-2020.6.20 cycler-0.10.0 kiwisolver-1.2.0 matplotlib-3.3.2 pillow-8.0.0 pyparsing-2.4.7

# %% [markdown]
# -reduce size
# -reduce complexity
# -reduce processing
# -increase performance
# -zoom image

# %%
import cv2 
import matplotlib.pyplot as plt

# %%
image = cv2.imread("C:\images\obama\obama1.jpeg")
plt.title('Original') 
plt.imshow(image)

# %%
resized = cv2.resize(image,(400,400))
plt.title('resized image')
plt.imshow(resized)
